# %% [markdown]
# # Поиск аниме по текстовому запросу
#
# Скрипт предназначен для поиска подходящего аниме по текстовому запросу. В нем загружаются данные аниме-фильмов из CSV-файла, извлекаются текстовые документы и их метки, а затем создается модель векторизации документов и обучения на основе метода опорных векторов (LinearSVC).
#
# Для обработки текстовых данных в скрипте используется модуль "TfidfVectorizer", который преобразует текст в числовой вектор в соответствии с частотами терминов, а также удаляет стоп-слова (частые слова, не несущие особой смысловой нагрузки).
#
# В конце скрипта, используя обученную модель, производится классификация новых документов на основе ключевых слов, введенных пользователем, и поиск подходящих аниме-фильмов. Результаты выводятся в форматированном HTML-коде с информацией о названии, описании, жанрах, тегах, соответствующих ключевым словам. Скрипт "find_anime.py" удобен для быстрого поиска и сравнения аниме-фильмов и может быть использован любителями и профессионалами в этой области.

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd

from IPython.display import display, HTML

# %%
# Загружаем набор данных из файла 
df = pd.read_csv('../data/raw/raw_findanime.csv', index_col=0, header=)

# %%
# Выводим первые 5 объектов
df.head(5)
# Out:
#                                                Title  \
# 0  Ходячий замок (Howl's Moving Castle: Howl no U...
# 1  Унесённые призраками (Spirited Away: Sen to Ch...
# 2  Стальной Алхимик: Братство [ТВ-2] (FullMetal A...
# 3  Волейбол! 2 (Haikyuu!! Second Season: Haikyu!!...
# 4  В лесу мерцания светлячков (Into the Forest of...
#
#                          Short title  \
# 0                      Ходячий замок
# 1               Унесённые призраками
# 2  Стальной Алхимик: Братство [ТВ-2]
# 3                        Волейбол! 2
# 4         В лесу мерцания светлячков
#
#                                                 Href Translation  \
# 0              https://findanime.net/hodiachii_zamok  переведено
# 1         https://findanime.net/unesennye_prizrakami  переведено
# 2  https://findanime.net/stalnoi_alhimik__bratstv...  переведено
# 3           https://findanime.net/voleibol__2__A5678  переведено
# 4  https://findanime.net/into_the_forest_of_firef...  переведено
#
#                                          Description  Count episodes  \
# 0  «Ходячий замок» — полнометражное аниме, выпуще...             1.0
# 1  Вместе с родителями маленькая Тихиро переезжае...             1.0
# 2  Нарушив главный запрет Алхимии и попытавшись в...            68.0
# 3  После участия в межшкольном чемпионате, волейб...            25.0
# 4  Маленькая девочка заблудилась в лесу, но вдруг...             1.0
#
#                                               Genres  Rating  Rating count  \
# 0  ['паропанк', 'фэнтези', 'сказка', 'приключения...     4.9           4.9
# 1  ['приключения', 'мистика', 'драма', 'семейный'...     4.9           5.0
# 2  ['война', 'драма', 'комедия', 'паропанк', 'фэн...     4.9           4.9
# 3    ['комедия', 'сёнэн', 'драма', 'спорт', 'школа']     4.9           4.9
# 4  ['мистика', 'сёдзё', 'романтика', 'трагедия', ...     4.8           4.7
#
#    World rating  ...  Character designers  \
# 0           4.9  ...  ['Ямасита Акихико']
# 1           4.9  ...      ['Андо Масаси']
# 2           4.9  ...     ['Канно Хироки']
# 3           4.9  ...  ['Кисида Такахиро']
# 4           4.8  ...                   []
#
#                                           Characters  \
# 0                            ['Софи Хаттер', 'Хаул']
# 1    ['Тихиро Огино', 'Хаку (Унесённые призраками)']
# 2                                                 []
# 3  ['Кэйдзи Акаси', 'Хитока Яти', 'Кэндзи Футакут...
# 4                                                 []
#
#                                               Seiyuu  \
# 0                    ['Байсё Тиэко', 'Кимура Такуя']
# 1  ['Тамай Юми', 'Хиираги Руми', 'Ирино Мию', 'Ка...
# 2  ['Фудзивара Кэйдзи', 'Ёсино Хироюки (сэйю)', '...
# 3  ['Хосоя Ёсимаса', 'Морикубо Сётаро', 'Нака Хир...
# 4                     ['Утияма Коки', 'Сакура Аянэ']
#
#                                          Translators  \
# 0                                     ['ReaniMedia']
# 1                                                 []
# 2  ['Ancord', 'MiraiDuB', 'AlFair Studio', 'AniDu...
# 3  ['AniPlay.TV', 'AniStar', 'AniLibria.TV', 'AOS...
# 4  ['LE-Production', 'AniWave', 'Akari GROUP', 'A...
#
#                                                 Tags Popularity  \
# 0                                                 []        3.0
# 1                                                 []        3.0
# 2  ['Холодное оружие', 'Империи', 'Дружба', 'Учит...        3.0
# 3  ['Несколько ГГ', 'Дружба', 'Волейбол', 'Спорти...        3.0
# 4                                                 []        3.0
#
#                                              Reviews  \
# 0  ['\xa0 \xa0 "Ходячий замок Хаула", в другой тр...
# 1  [' Лет 10-12 назад (уж и не помню точно) зашла...
# 2  ['\xa0 \xa0Тема сравнения двух версий сериала ...
# 3  ['Вот и дошли руки написать отзыв о втором сез...
# 4  ['"И максимальной оценки будет мало..."Могу че...
#
#                                               Quotes  \
# 0  ['Прости меня, я такая капуша: ты ждал меня вс...
# 1  ['Если забудешь своё имя, то не сможешь вернут...
# 2  ['- Мне нравится эта вечная зима. Всё либо чер...
# 3                                                 []
# 4                                                 []
#
#                                        Similar anime  \
# 0  ['Навсикая из Долины Ветров', 'Унесённые призр...
# 1  ['Ходячий замок', 'Мой сосед Тоторо', 'Тетрадь...
# 2                        ['Стальной Алхимик [ТВ-1]']
# 3  ['Баскетбол Куроко [ТВ-1]', 'Синяя тюрьма: Блю...
# 4  ['Тетрадь дружбы Нацумэ', 'Сад изящных слов', ...
#
#                                            Image src
# 0  https://static.findanime.net/uploads/pics/00/1...
# 1  https://static.findanime.net/uploads/pics/00/1...
# 2  https://static.findanime.net/uploads/pics/00/1...
# 3  https://static.findanime.net/uploads/pics/00/4...
# 4  https://static.findanime.net/uploads/pics/00/1...
#
# [5 rows x 30 columns]

# %%
# Загружаем стоп-слова для русского языка
stop_words = [
    "бы",
    "был",
    "была",
    "были",
    "вам",
    "вас",
    "весь",
    "во",
    "вот",
    "все",
    "всей",
    "вы",
    "да",
    "для",
    "его",
    "ее",
    "ей",
    "ею",
    "если",
    "есть",
    "еще",
    "же",
    "за",
    "или",
    "им",
    "их",
    "как",
    "кем",
    "ко",
    "когда",
    "кто",
    "ли",
    "лучше",
    "меня",
    "мне",
    "много",
    "может",
    "мы",
    "на",
    "надо",
    "нас",
    "не",
    "него",
    "нее",
    "нет",
    "них",
    "но",
    "ну",
    "о",
    "об",
    "однако",
    "он",
    "она",
    "они",
    "оно",
    "от",
    "очень",
    "по",
    "под",
    "при",
    "с",
    "со",
    "так",
    "также",
    "такой",
    "там",
    "те",
    "тебя",
    "тем",
    "теперь",
    "то",
    "тогда",
    "того",
    "том",
    "ты",
    "уже",
    "хотя",
    "чего",
    "чей",
    "чем",
    "что",
    "чтобы",
    "эта",
    "эти",
    "это",
    "я",
]

# Образец набора данных
data = []
for i in range(4000):
    anime = {
        "название": df.loc[i, "Title"],
        "жанр": df.loc[i, "Genres"],
        "теги": df.loc[i, "Tags"],
        "описание": str(df.loc[i, "Description"]),
        "цитаты": df.loc[i, "Quotes"],
    }
    data.append(anime)

# %%
# Разбиваем данные на текстовые документы и их метки
documents = []
labels = []
for anime in data:
    # Удаляем стоп-слова из текста
    text = " ".join(
        [word for word in anime["название"].split() if word.lower()
         not in stop_words]
    )
    text += " ".join(
        [word for word in anime["жанр"].split() if word.lower() not in stop_words]
    )
    text += " ".join(
        [word for word in anime["теги"].split() if word.lower() not in stop_words]
    )
    text += " ".join(
        [word for word in anime["описание"].split() if word.lower()
         not in stop_words]
    )
    text += " ".join(
        [word for word in anime["цитаты"].split() if word.lower()
         not in stop_words]
    )
    documents.append(text)
    labels.append(anime["название"])

# %%
# Создаём модель для векторизации документов и обучения
vectorizer = TfidfVectorizer()
classifier = LinearSVC()

# Обучаем модель на обучающих данных
train_vectors = vectorizer.fit_transform(documents)
classifier.fit(train_vectors, labels)
# Out:
# LinearSVC()

# %%
# Несколько примеров текстовых запросов, по которым нужно найти аниме
keywords_str_list = [
    "историческое франция",
    "ниндзя, кровь",
    "драма экшн интрига америка",
    "школа любовь треугольник",
]

# Предсказание и вывод результата
for i, keywords_str in enumerate(keywords_str_list):
    keywords = keywords_str.split()
    new_document = " ".join(keywords)

    new_vector = vectorizer.transform([new_document])
    predicted_names = classifier.predict(new_vector)
    title = predicted_names[0]
    row = df.loc[df["Title"] == title]
    description = row.iloc[0]["Description"]
    genres = row.iloc[0]["Genres"]
    tags = row.iloc[0]["Tags"]

    # Отображаем описание, обернутое в HTML-теги, для форматирования:
    html_description = '{}. Ключевые слова: {}<p>Название: {}<p>Жанры: {}<p>Теги: {}<p><div style="white-space: pre-line">{}</div>'.format(
        i + 1, keywords, title, genres, tags, description
    )
    display(HTML(html_description))
# Out:
# 1. Ключевые слова: ['историческое', 'франция']<p>Название: Отверженные: Козетта (Les Miserables: Shoujo Cosette)<p>Жанры: ['исторический', 'повседневность', 'семейный', 'драма']<p>Теги: []<p><div style="white-space: pre-line">На основе романа Виктора Гюго. Франция, 19 век. Маленькая Козетта путешествует по стране вместе с мамой в поисках работы и пропитания. Однако, никто не хочет давать работу матери-одиночке. Отчаявшись, мать решает временно оставить девочку под опеку семьи Тенардье и отправляется на поиски работы в большой город. Но это было ошибкой. Взяв деньги с матери и пообещав заботиться о Козетте, Тернадье превратили девочку в служанку и издевались над ней.(с)Kamitake для Findanime.ru</div>
# 2. Ключевые слова: ['ниндзя,', 'кровь']<p>Название: Владыка Скрытого мира (The King of Nabari: Nabari no Ou)<p>Жанры: ['сёнэн', 'приключения', 'драма', 'фэнтези', 'подтекст и персонажи BL/GL', 'комедия']<p>Теги: ['Спасение мира', 'Ниндзя', 'ГГ мужчина', 'Навыки', 'Дружба', 'Борьба за власть']<p><div style="white-space: pre-line">14-летний Михару Рокудзё хорошо знает, что он не такой, как все. Тайный дар Сотворения стал его проклятием с детских лет. Мальчик рано потерял родителей и стал сторониться людей, не желая, чтобы из-за него кто-то еще страдал. А все дело в том, что только дар Сотворения дает владельцу право претендовать на титул владыки Набари – тайного мира ниндзя (которых в Японии, как известно, пруд пруди). Большинство синоби объединилось под знаменами могущественного клана Ига, чтобы захватить Михару и использовать его дар, и лишь редкие кланы и ниндзя-одиночки осмелились встать на его защиту. В итоге, вокруг главного героя собирается команда из учителя Кумохиры и двух одноклассников – отличника Койити и взбалмошной…</div>
# 3. Ключевые слова: ['драма', 'экшн', 'интрига', 'америка']<p>Название: Фантом (Phantom: Requiem for the Phantom)<p>Жанры: ['драма', 'экшн', 'трагедия', 'триллер', 'психология', 'сэйнэн']<p>Теги: ['Убийцы', 'Мафия', 'Любовный треугольник', 'Антигерой', 'ГГ мужчина', 'Амнезия', 'Сокрытие личности']<p><div style="white-space: pre-line">Америка кишит мафией, и заказное убийство посреди бела дня для нее - не редкость. За большую их часть ответственна таинственная организация "Инферно", использующая Фантома - практически непобедимого суперсолдата. Однажды простой японский турист становится очевидцем убийства, совершенного Фантомом. В отчаянии он пытается сбежать и скрывается в одиноком здании, но и там его находит Айн, действовавшая под позывным "Фантом", и ее руководитель. Пойманному парню промывают мозги. Теперь некогда миролюбивый турист - марионетка в руках "Инферно" под именем Цвай. Его бросили в мир лжи, предательств и жестокости, и он должен в нем выживать. Единственное, на что он надеется - что у нему вернется память,…</div>
# 4. Ключевые слова: ['школа', 'любовь', 'треугольник']<p>Название: Любит — не любит (Love, Be Loved, Leave, Be Left: Omoi, Omoware, Furi, Furare)<p>Жанры: ['романтика', 'сёдзё', 'школа']<p>Теги: ['Любовь с первого взгляда', 'Сосед/ка', 'Брат и сестра', 'Несколько ГГ', 'Любовный треугольник', 'Дружба']<p><div style="white-space: pre-line">Четверо ребят заселяются в один дом перед началом нового учебного года. Две девушки, уверенная в себе реалистка Акари и стеснительная мечтательница Юна, быстро становятся подругами, но имеют противоположные взгляды на любовь, построенные на их личных качествах: Юна мечтает о конфетно-букетном романтическом чувстве, тогда как для Акари такие отношения кажутся неправдоподобными и далекими от жизни. Брат Акари и друг детства Юны тоже по-разному видят отношения: хитрый плейбой Рио готов встречаться с любой симпатичной девушкой, которая признается ему в любви, а наивный и отзывчивый Кадзуоми просто не понимает что же это такое - "любить". Что ждет их, любовь или дружба? А если любовь - та ли самая,…</div>
